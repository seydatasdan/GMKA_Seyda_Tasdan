# %% [markdown]
# <a href="https://colab.research.google.com/github/seydatasdan/GMKA_Seyda_Tasdan/blob/main/Odev3_Python_Veri_Analizi_Egitimi__%C5%9Eeyda_Ta%C5%9Fdan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Güney Marmara ve TRAI
# # <center> Python Veri Analizi Eğitimi
# # <center> Ödev 3

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf
import plotly.express as px
import plotly.graph_objects as go
import plotly.graph_objs as xaxis
from plotly.subplots import make_subplots
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### 2021 EUR/TRY kur tablosunun incelenmesi

# %% [markdown]
# 1. <i> Yahoo Finance</i> sitesinden 2021 yılına ait EUR/TRY kur değerlerini indiriniz

# %%
EUR_TRY = yf.download('EURTRY=X', start='2021-01-01', end='2021-12-31')
EUR_TRY
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2021-01-01   9.08470   9.08470   9.08470   9.08470    9.08470       0
# 2021-01-04   9.11047   9.11154   8.99617   9.10568    9.10568       0
# 2021-01-05   9.09273   9.11239   9.04298   9.08882    9.08882       0
# 2021-01-06   9.08044   9.09500   8.92864   9.08177    9.08177       0
# 2021-01-07   9.00475   9.07176   8.88154   9.00614    9.00614       0
# ...              ...       ...       ...       ...        ...     ...
# 2021-12-24  12.79533  13.67650  12.51641  12.79752   12.79752       0
# 2021-12-27  12.28318  13.03196  12.16917  12.23056   12.23056       0
# 2021-12-28  12.96156  13.47629  12.88283  13.05254   13.05254       0
# 2021-12-29  13.35232  14.37038  13.31566  13.35252   13.35252       0
# 2021-12-30  14.32090  15.11444  14.05750  14.31055   14.31055       0
#
# [260 rows x 6 columns]

# %% [markdown]
# 2. Veriyi özet metodları ile inceleyiniz

# %%
EUR_TRY.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2021-01-01  9.08470  9.08470  9.08470  9.08470    9.08470       0
# 2021-01-04  9.11047  9.11154  8.99617  9.10568    9.10568       0
# 2021-01-05  9.09273  9.11239  9.04298  9.08882    9.08882       0
# 2021-01-06  9.08044  9.09500  8.92864  9.08177    9.08177       0
# 2021-01-07  9.00475  9.07176  8.88154  9.00614    9.00614       0

# %%
EUR_TRY.describe()
# Out:
#              Open        High         Low       Close   Adj Close  Volume
# count  260.000000  260.000000  260.000000  260.000000  260.000000   260.0
# mean    10.434622   10.573510   10.347226   10.439140   10.439140     0.0
# std      1.754535    1.940096    1.688033    1.753083    1.753083     0.0
# min      8.386340    8.464750    8.354830    8.387260    8.387260     0.0
# 25%      9.621848    9.695410    9.550110    9.629247    9.629247     0.0
# 50%     10.088800   10.146105   10.047840   10.089370   10.089370     0.0
# 75%     10.439128   10.471000   10.358152   10.442483   10.442483     0.0
# max     18.671040   20.733000   18.657669   18.655109   18.655109     0.0

# %% [markdown]
# 3. Veri temizleme: <br>
# 	• Tabloda sadece "Adj Close" (düzeltilmiş kapanış) sütununu bırakınız.<br>
# 	• "Adj Close" sütununu " Kapanış (TRY)" olarak yeniden adlandırınız.

# %%
EUR_TRY = EUR_TRY[['Adj Close']]
EUR_TRY.columns=["Kapanış(TRY)"]
EUR_TRY
# Out:
#             Kapanış(TRY)
# Date
# 2021-01-01       9.08470
# 2021-01-04       9.10568
# 2021-01-05       9.08882
# 2021-01-06       9.08177
# 2021-01-07       9.00614
# ...                  ...
# 2021-12-24      12.79752
# 2021-12-27      12.23056
# 2021-12-28      13.05254
# 2021-12-29      13.35252
# 2021-12-30      14.31055
#
# [260 rows x 1 columns]

# %% [markdown]
# 4. Tabloya yeni sütun ekleme:<br>
# 	• Tabloya yeni bir sütun ekleyerek Kapanış (TRY) değerlerini 1 Ocak 2021 tarihindeki kapanış değerine göre normalize ediniz.<br>
# 	• BIST30 endeksinin 2021 yılı boyunca değişimini yorumlayınız.

# %%
norm = EUR_TRY.iloc[0,0]   # iloc belli bir konumdaki verileri seçmek için kullanılır
EUR_TRY['Normalize'] = EUR_TRY['Kapanış(TRY)'] / norm
EUR_TRY
# Out:
# <ipython-input-133-8627a181e5db>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Kapanış(TRY)  Normalize
# Date
# 2021-01-01       9.08470   1.000000
# 2021-01-04       9.10568   1.002309
# 2021-01-05       9.08882   1.000454
# 2021-01-06       9.08177   0.999678
# 2021-01-07       9.00614   0.991353
# ...                  ...        ...
# 2021-12-24      12.79752   1.408689
# 2021-12-27      12.23056   1.346281
# 2021-12-28      13.05254   1.436761
# 2021-12-29      13.35252   1.469781
# 2021-12-30      14.31055   1.575236
#
# [260 rows x 2 columns]

# %% [markdown]
# BIST30 endeksi 2021 yılı boyunca artış göstermiştir.

# %% [markdown]
# 5. Veriyi grafik olarak inceleyiniz:<br>
# 	• Tabloyu px grafiği olarak görselleştiriniz.<br>
# 	• Tabloyu go. grafiği olarak görselleştiriniz.

# %%
fig = px.line(EUR_TRY, y='Normalize', title='BIST30 Endeksi 2021 Yılı',
              labels = {'Date': 'Tarih', 'Normalize':'BIST 30 Endeksi'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=EUR_TRY.index, y=EUR_TRY['Normalize'], 
                         mode='markers', name='BIST30 Endeksi'))

fig.update_layout(title='BIST30 Endeksi 2021 Yılı',
                  xaxis_title='Tarih',
                  yaxis_title='BIST30 Endeksi')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2021 ve 2022 değerlerini birlikte inceleme

# %% [markdown]
# 1. <i> Yahoo Finance</i> sitesinden 2022 BIST30 ve EUR/TRY kur değerlerini indiriniz

# %%
B30 = yf.download('XU030.IS', start = '2022-01-01' , end = '2022-12-31')
EUR_TRY = yf.download('EURTRY=X', start='2021-01-01', end='2021-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 2. Indirdiğiniz verileri 2021 verilerini temizleyip düzenlediğiniz üzere hazırlayınız.

# %%
B30 = yf.download('TRY=X', start = '2021-01-01' , end = '2021-12-31')
B30 = B30[B30.index>'2021-01-01']
B30 = B30[['Adj Close']]
B30.columns = ['Kapanış(TRY)']
B30['Normalize'] = B30['Kapanış(TRY)']/B30.iloc[0,0]
B30
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Kapanış(TRY)  Normalize
# Date
# 2021-01-04       7.43342   1.000000
# 2021-01-05       7.42150   0.998396
# 2021-01-06       7.38379   0.993323
# 2021-01-07       7.29972   0.982014
# 2021-01-08       7.32660   0.985630
# ...                  ...        ...
# 2021-12-24      11.41330   1.535404
# 2021-12-27      10.80707   1.453849
# 2021-12-28      11.52105   1.549899
# 2021-12-29      11.80312   1.587845
# 2021-12-30      12.64030   1.700469
#
# [259 rows x 2 columns]

# %%
EUR_TRY = yf.download('TRY=X', start = '2021-01-01' , end = '2021-12-31')
EUR_TRY = EUR_TRY[EUR_TRY.index>'2021-01-01']
EUR_TRY = EUR_TRY[['Adj Close']]
EUR_TRY.columns = ['EUR/TRY']
EUR_TRY['Normalize EUR/TRY'] = EUR_TRY['EUR/TRY']/EUR_TRY.iloc[0,0]
EUR_TRY
# Out:
# [*********************100%***********************]  1 of 1 completed
#              EUR/TRY  Normalize EUR/TRY
# Date
# 2021-01-04   7.43342           1.000000
# 2021-01-05   7.42150           0.998396
# 2021-01-06   7.38379           0.993323
# 2021-01-07   7.29972           0.982014
# 2021-01-08   7.32660           0.985630
# ...              ...                ...
# 2021-12-24  11.41330           1.535404
# 2021-12-27  10.80707           1.453849
# 2021-12-28  11.52105           1.549899
# 2021-12-29  11.80312           1.587845
# 2021-12-30  12.64030           1.700469
#
# [259 rows x 2 columns]

# %% [markdown]
# 3. 2021 ve 2022 veri tablolarını tek bir tablo haline getiriniz.

# %%
indirme_listesi=['XU100.IS' , 'TRY=X']
Veri = pd.DataFrame()

for i in indirme_listesi:
  data = yf.download(i, start = '2021-01-01' , end = '2022-12-31')
  data = data['Adj Close'].rename(i)
  Veri = pd.concat([Veri, data], axis = 1)

Veri
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                XU100.IS      TRY=X
# 2021-01-04  1495.400024   7.433420
# 2021-01-05  1489.599976   7.421500
# 2021-01-06  1505.400024   7.383790
# 2021-01-07  1522.199951   7.299720
# 2021-01-08  1540.599976   7.326600
# ...                 ...        ...
# 2022-05-19          NaN  15.956300
# 2022-07-11          NaN  17.271601
# 2022-07-12          NaN  17.344700
# 2022-07-15          NaN  17.464100
# 2022-08-30          NaN  18.180000
#
# [521 rows x 2 columns]

# %%
Veri.columns=['Kapanış(TRY)', 'EUR/TRY']
Veri = Veri[Veri['Kapanış(TRY)'] > 0 ]
Veri
# Out:
#             Kapanış(TRY)    EUR/TRY
# 2021-01-04   1495.400024   7.433420
# 2021-01-05   1489.599976   7.421500
# 2021-01-06   1505.400024   7.383790
# 2021-01-07   1522.199951   7.299720
# 2021-01-08   1540.599976   7.326600
# ...                  ...        ...
# 2022-12-26   5504.100098  18.623430
# 2022-12-27   5434.500000  18.656799
# 2022-12-28   5345.600098  18.657000
# 2022-12-29   5476.899902  18.693670
# 2022-12-30   5509.200195  18.702990
#
# [500 rows x 2 columns]

# %%
Veri_2022 = B30[['Kapanış(TRY)', 'Normalize']]
Veri_2022
# Out:
#             Kapanış(TRY)  Normalize
# Date
# 2021-01-04       7.43342   1.000000
# 2021-01-05       7.42150   0.998396
# 2021-01-06       7.38379   0.993323
# 2021-01-07       7.29972   0.982014
# 2021-01-08       7.32660   0.985630
# ...                  ...        ...
# 2021-12-24      11.41330   1.535404
# 2021-12-27      10.80707   1.453849
# 2021-12-28      11.52105   1.549899
# 2021-12-29      11.80312   1.587845
# 2021-12-30      12.64030   1.700469
#
# [259 rows x 2 columns]

# %%
Veri = pd.concat([Veri_2022, Veri], axis = 0 )   
Veri
# Out:
#             Kapanış(TRY)  Normalize    EUR/TRY
# 2021-01-04      7.433420   1.000000        NaN
# 2021-01-05      7.421500   0.998396        NaN
# 2021-01-06      7.383790   0.993323        NaN
# 2021-01-07      7.299720   0.982014        NaN
# 2021-01-08      7.326600   0.985630        NaN
# ...                  ...        ...        ...
# 2022-12-26   5504.100098        NaN  18.623430
# 2022-12-27   5434.500000        NaN  18.656799
# 2022-12-28   5345.600098        NaN  18.657000
# 2022-12-29   5476.899902        NaN  18.693670
# 2022-12-30   5509.200195        NaN  18.702990
#
# [1536 rows x 3 columns]

# %%
Veri['Normalize'] = Veri['Kapanış(TRY)']/Veri.iloc[0,0]
Veri['Normalize EUR/TRY'] = Veri['EUR/TRY']/Veri.iloc[0,1]
Veri['degisim'] = Veri['Normalize'].diff(1)
Veri['d_yon'] = Veri['degisim'].map(lambda x: 'düşen gün' if x<0 else 'yükselen gün')
Veri['degisim%'] = (Veri['degisim']/Veri['Normalize'].shift())
Veri
# Out:
#             Kapanış(TRY)   Normalize    EUR/TRY    degisim         d_yon  \
# 2021-01-04      7.433420    1.000000        NaN        NaN  yükselen gün
# 2021-01-05      7.421500    0.998396        NaN  -0.001604     düşen gün
# 2021-01-06      7.383790    0.993323        NaN  -0.005073     düşen gün
# 2021-01-07      7.299720    0.982014        NaN  -0.011310     düşen gün
# 2021-01-08      7.326600    0.985630        NaN   0.003616  yükselen gün
# ...                  ...         ...        ...        ...           ...
# 2022-12-26   5504.100098  740.453245  18.623430   6.632249  yükselen gün
# 2022-12-27   5434.500000  731.090113  18.656799  -9.363132     düşen gün
# 2022-12-28   5345.600098  719.130625  18.657000 -11.959488     düşen gün
# 2022-12-29   5476.899902  736.794069  18.693670  17.663444  yükselen gün
# 2022-12-30   5509.200195  741.139349  18.702990   4.345280  yükselen gün
#
#             degisim%  Normalize EUR/TRY
# 2021-01-04       NaN                NaN
# ...

# %% [markdown]
# 4. Veriyi grafik olarak inceleyiniz:<br>
# 	• Tabloları px grafiği olarak görselleştiriniz.<br>
# 	• Tabloları go. grafiği olarak görselleştiriniz.<br>
# 	• Tabloları subplots grafiği olarak görselleştiriniz.

# %%
fig = px.line(Veri, y='Normalize', title='BIST30 ve EUR/TRY',
              labels = {'Date': 'Tarih', 'Normalize':'BIST 30 Endeksi'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=Veri.index, y= Veri['Normalize'] , name='Normalize BIST 100'))
fig.add_trace(go.Scatter(x=Veri.index, y= Veri['Normalize EUR/TRY'], name='Normalize EUR/TRY'))

fig.update_layout(title = 'Normalize BIST 100 ve Normalize Kur',
                  xaxis_title = 'Tarih', xaxis_dtick ='M1',
                  yaxis_title = 'Kapanış (TRY)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.02)

fig.add_trace(
    go.Scatter(x=Veri.index, y=Veri['Kapanış(TRY)'], name='BIST 30 Endeksi'),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=Veri.index, y=Veri['EUR/TRY'], name='EUR/TRY'),
    row=2, col=1
)

fig.update_layout(height=600, title_text="BIST 30 Endeksi ve EUR/TRY",
                  xaxis_title="Tarih", yaxis_title="Kapanış (TRY)")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
